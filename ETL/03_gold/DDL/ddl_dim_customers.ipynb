-- %%
-- DDL for Customers Dimension with automatic constraints
CREATE SCHEMA IF NOT EXISTS ecommerce_gold;

-- %%
DROP TABLE IF EXISTS ecommerce_gold.dim_customers;

-- %%
CREATE TABLE IF NOT EXISTS ecommerce_gold.dim_customers (
    customer_key STRING,
    customer_id INT,
    region STRING,
    customer_rating DOUBLE
) USING DELTA;

-- %%
-- High-quality automatic check
ALTER TABLE ecommerce_gold.dim_customers ADD CONSTRAINT chk_gold_cust_id CHECK (customer_id IS NOT NULL);
