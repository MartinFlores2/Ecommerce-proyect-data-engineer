-- %%
-- DDL for Products Dimension with Constraints
CREATE TABLE IF NOT EXISTS ecommerce_gold.dim_products (
    product_category STRING
) USING DELTA;

-- Automatic quality constraint
ALTER TABLE ecommerce_gold.dim_products ADD CONSTRAINT chk_gold_product_cat CHECK (product_category IS NOT NULL);
