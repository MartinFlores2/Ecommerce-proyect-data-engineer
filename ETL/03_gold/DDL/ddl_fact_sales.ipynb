-- %%
DROP TABLE IF EXISTS ecommerce_gold.fact_sales;

-- %%
-- DDL for Fact Sales Table with Constraints
CREATE TABLE IF NOT EXISTS ecommerce_gold.fact_sales (
    order_id STRING,
    customer_key STRING,
    product_category STRING,
    revenue DOUBLE,
    order_date DATE
) USING DELTA;

ALTER TABLE ecommerce_gold.fact_sales ADD CONSTRAINT chk_gold_fact_order_id CHECK (order_id IS NOT NULL);
